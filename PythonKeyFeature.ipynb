# %% [markdown]
# #Python Key Feature
# ###Version_版本号：2.7.6

# %%
import sys
sys.version
# Out:
# '2.7.6 (default, Sep  9 2014, 15:04:36) \n[GCC 4.2.1 Compatible Apple LLVM 6.0 (clang-600.0.39)]'

# %% [markdown]
# ###Key words_关键字：31

# %%
import keyword
keyword.kwlist

import pandas as pd
pd.set_option('display.max_rows',100) 
kwframe = pd.DataFrame({'Name_名称': keyword.kwlist,'Function_功能':range(0,31), 'Example_举例':range(0,31)},
                       index=range(0,31),
                       columns=['Name_名称','Function_功能','Example_举例'])

# df[row][column] is two operations, df.iloc[row,columns] is one operation.
kwframe.iloc[0,1]='&';kwframe.iloc[0,2]=''
kwframe.iloc[1,1]='';kwframe.iloc[1,2]=''
kwframe.iloc[2,1]='';kwframe.iloc[2,2]=''
kwframe.iloc[3,1]='';kwframe.iloc[3,2]=''
kwframe.iloc[4,1]='';kwframe.iloc[4,2]=''
kwframe.iloc[5,1]='';kwframe.iloc[5,2]=''
kwframe.iloc[6,1]='';kwframe.iloc[6,2]=''
kwframe.iloc[7,1]='';kwframe.iloc[7,2]=''
kwframe.iloc[8,1]='';kwframe.iloc[8,2]=''
kwframe.iloc[9,1]='';kwframe.iloc[9,2]=''
kwframe.iloc[10,1]='';kwframe.iloc[10,2]=''

kwframe.iloc[10,1]='';kwframe.iloc[10,2]=''
kwframe.iloc[11,1]='';kwframe.iloc[11,2]=''
kwframe.iloc[12,1]='';kwframe.iloc[12,2]=''
kwframe.iloc[13,1]='';kwframe.iloc[13,2]=''
kwframe.iloc[14,1]='';kwframe.iloc[14,2]=''
kwframe.iloc[15,1]='';kwframe.iloc[15,2]=''
kwframe.iloc[16,1]='';kwframe.iloc[16,2]=''
kwframe.iloc[17,1]='';kwframe.iloc[17,2]=''
kwframe.iloc[18,1]='';kwframe.iloc[18,2]=''
kwframe.iloc[19,1]='';kwframe.iloc[19,2]=''
kwframe.iloc[20,1]='';kwframe.iloc[20,2]=''

kwframe.iloc[21,1]='';kwframe.iloc[21,2]=''
kwframe.iloc[22,1]='';kwframe.iloc[22,2]=''
kwframe.iloc[23,1]='';kwframe.iloc[23,2]=''
kwframe.iloc[24,1]='';kwframe.iloc[24,2]=''
kwframe.iloc[25,1]='';kwframe.iloc[25,2]=''
kwframe.iloc[26,1]='';kwframe.iloc[26,2]=''
kwframe.iloc[27,1]='';kwframe.iloc[27,2]=''
kwframe.iloc[28,1]='';kwframe.iloc[28,2]=''
kwframe.iloc[29,1]='';kwframe.iloc[29,2]=''
kwframe.iloc[30,1]='';kwframe.iloc[30,2]=''


kwframe
# Out:
#      Name_名称 Function_功能 Example_举例
# 0        and           &
# 1         as
# 2     assert
# 3      break
# 4      class
# 5   continue
# 6        def
# 7        del
# 8       elif
# 9       else
# 10    except
# 11      exec
# 12   finally
# 13       for
# 14      from
# 15    global
# 16        if
# 17    import
# 18        in
# 19        is
# 20    lambda
# 21       not
# 22        or
# 23      pass
# 24     print
# 25     raise
# 26    return
# 27       try
# 28     while
# 29      with
# 30     yield

# %% [markdown]
# #Buildin functions_内置函数：85

# %%
import string
alc = string.ascii_lowercase
bif = [i for i in dir(__builtins__) if any(i.startswith(j) for j in alc)]
bif

import pandas as pd
pd.set_option('display.max_rows',100) 
pd.set_option('display.max_colwidth',100) 
y = pd.DataFrame({'Name_名称':bif,'Function_功能':range(0,85), 'Example_举例':range(0,85)}, columns=['Name_名称','Function_功能','Example_举例'])
y.iloc[0,1]='Return absolute value of a number_返回参数的绝对值'; y.iloc[0,2]=''
y.iloc[1,1]='Return True if all items are True_返回参数全部为真的布林值'; y.iloc[1,2]='all(5>j for j in [3,4,2])>>>True'
y.iloc[2,1]='Reture Ture is any items is True_返回参数任意为真的布林值'; y.iloc[2,2]='any(j>5 for j in [3,4,2])>>>False'
y.iloc[3,1]='test'; y.iloc[3,2]='test'
y.iloc[4,1]='test'; y.iloc[4,2]='test'
y.iloc[5,1]='test'; y.iloc[5,2]='test'
y.iloc[6,1]='test'; y.iloc[6,2]='test'
y.iloc[7,1]='test'; y.iloc[7,2]='test'
y.iloc[8,1]='test'; y.iloc[8,2]='test'
y.iloc[9,1]='test'; y.iloc[9,2]='test'
y.iloc[10,1]='test'; y.iloc[10,2]='test'

y.iloc[11,1]='Return a string by the ASCII number_返回 ASCII 编码对应的字符'; y.iloc[11,2]='chr(255)'
y.iloc[12,1]='test'; y.iloc[12,2]='test'
y.iloc[13,1]='Return 1,0,-1 for compare >=<'; y.iloc[13,2]='cmp(1,2)'
y.iloc[14,1]='test'; y.iloc[14,2]='test'
y.iloc[15,1]='test'; y.iloc[15,2]='test'
y.iloc[16,1]='test'; y.iloc[16,2]='test'
y.iloc[17,1]='test'; y.iloc[17,2]='test'
y.iloc[18,1]='test'; y.iloc[18,2]='test'
y.iloc[19,1]='test'; y.iloc[19,2]='test'
y.iloc[20,1]='test'; y.iloc[20,2]='test'

y.iloc[21,1]='Return scope names or object''s attributes_返回域变量名或对象属性列表'; y.iloc[21,2]='dir(),dir(Inter)'
y.iloc[22,1]='test'; y.iloc[22,2]='test'
y.iloc[23,1]='test'; y.iloc[23,2]='test'
y.iloc[24,1]='Return tuples of count and value_返回编号与值得元组'; y.iloc[24,2]="list(enumerate(list('abc')))>>>[(0, 'a'), (1, 'b'), (2, 'c')]"
y.iloc[25,1]='test'; y.iloc[25,2]='test'
y.iloc[26,1]='test'; y.iloc[26,2]='test'
y.iloc[27,1]='test'; y.iloc[27,2]='test'
y.iloc[28,1]='test'; y.iloc[28,2]='test'
y.iloc[29,1]='test'; y.iloc[29,2]='test'
y.iloc[30,1]='test'; y.iloc[30,2]='test'

y.iloc[31,1]='test'; y.iloc[31,2]='test'
y.iloc[32,1]='test'; y.iloc[32,2]='test'
y.iloc[33,1]='test'; y.iloc[33,2]='test'
y.iloc[34,1]='test'; y.iloc[34,2]='test'
y.iloc[35,1]='test'; y.iloc[35,2]='test'
y.iloc[36,1]='Return the hash value_返回哈希值'; y.iloc[36,2]='hash(1)==hash(1.0)>>>True'
y.iloc[37,1]='test'; y.iloc[37,2]='test'
y.iloc[38,1]='test'; y.iloc[38,2]='test'
y.iloc[39,1]="Return object's unique number during its lifetime_返回对象唯一编号"; y.iloc[39,2]=''
y.iloc[40,1]='test'; y.iloc[40,2]='test'

y.iloc[41,1]='test'; y.iloc[41,2]='test'
y.iloc[42,1]='test'; y.iloc[42,2]='test'
y.iloc[43,1]='test'; y.iloc[43,2]='test'
y.iloc[44,1]='test'; y.iloc[44,2]='test'
y.iloc[45,1]='test'; y.iloc[45,2]='test'
y.iloc[46,1]='Return the length of object_返回对象长度'; y.iloc[46,2]=''
y.iloc[47,1]='test'; y.iloc[47,2]='test'
y.iloc[48,1]='test'; y.iloc[48,2]='test'
y.iloc[49,1]='test'; y.iloc[49,2]='test'
y.iloc[50,1]='test'; y.iloc[50,2]='test'

y.iloc[51,1]='Apply function to everyitem and return a list of results'; y.iloc[51,2]="map(len,list('abc'))>>>[1,1,1]"
y.iloc[52,1]='Return max'; y.iloc[52,2]='test'
y.iloc[53,1]='test'; y.iloc[53,2]='test'
y.iloc[54,1]='Return min'; y.iloc[54,2]='test'
y.iloc[55,1]='test'; y.iloc[55,2]='test'
y.iloc[56,1]='test'; y.iloc[56,2]='test'
y.iloc[57,1]='test'; y.iloc[57,2]='test'
y.iloc[58,1]='test'; y.iloc[58,2]='test'
y.iloc[59,1]='test'; y.iloc[59,2]='test'
y.iloc[60,1]='test'; y.iloc[60,2]='test'

y.iloc[61,1]='test'; y.iloc[61,2]='test'
y.iloc[62,1]='test'; y.iloc[62,2]='test'
y.iloc[63,1]='test'; y.iloc[63,2]='test'
y.iloc[64,1]='test'; y.iloc[64,2]='test'
y.iloc[65,1]='test'; y.iloc[65,2]='test'
y.iloc[66,1]='test'; y.iloc[66,2]='test'
y.iloc[67,1]='test'; y.iloc[67,2]='test'
y.iloc[68,1]='test'; y.iloc[68,2]='test'
y.iloc[69,1]='test'; y.iloc[69,2]='test'
y.iloc[70,1]='test'; y.iloc[70,2]='test'

y.iloc[71,1]='test'; y.iloc[71,2]='test'
y.iloc[72,1]='test'; y.iloc[72,2]='test'
y.iloc[73,1]='test'; y.iloc[73,2]='test'
y.iloc[74,1]='test'; y.iloc[74,2]='test'
y.iloc[75,1]='test'; y.iloc[75,2]='test'
y.iloc[76,1]='test'; y.iloc[76,2]='test'
y.iloc[77,1]='test'; y.iloc[77,2]='test'
y.iloc[78,1]='test'; y.iloc[78,2]='test'
y.iloc[79,1]='test'; y.iloc[79,2]='test'
y.iloc[80,1]='test'; y.iloc[80,2]='test'

y.iloc[81,1]='test'; y.iloc[81,2]='test'
y.iloc[82,1]='test'; y.iloc[82,2]='test'
y.iloc[83,1]='test'; y.iloc[83,2]='test'
y.iloc[84,1]='test'; y.iloc[84,2]='test'

y
# Out:
#          Name_名称                                                 Function_功能  \
# 0            abs                  Return absolute value of a number_返回参数的绝对值
# 1            all              Return True if all items are True_返回参数全部为真的布林值
# 2            any               Reture Ture is any items is True_返回参数任意为真的布林值
# 3          apply                                                        test
# 4     basestring                                                        test
# 5            bin                                                        test
# 6           bool                                                        test
# 7         buffer                                                        test
# 8      bytearray                                                        test
# 9          bytes                                                        test
# 10      callable                                                        test
# ...

# %%
all(5>j for j in [3,4,2])
# Out:
# True

# %%
any(j>5 for j in [3,4,2])
# Out:
# False

# %%
chr(255)
# Out:
# '\xff'

# %%
cmp(1,2)
# Out:
# -1

# %%
list(enumerate(list('abc')))
# Out:
# [(0, 'a'), (1, 'b'), (2, 'c')]

# %%
hash(1)==hash(1.0)
# Out:
# True

# %%
id('a')
# Out:
# 4469949864

# %%
map(len,list('abc'))
# Out:
# [1, 1, 1]

# %%
max(range(1,200))
# Out:
# 199

# %%
min(range(1,200))
# Out:
# 1

# %% [markdown]
# #Libraries_所有模块

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# AVFoundation        _codecs_kr          filecmp             pyparsing
# Accounts            _codecs_tw          fileinput           pystache
# AddressBook         _collections        findertools         pytz
# AppKit              _csv                flask               queuelib
# AppleScriptKit      _ctypes             fnmatch             quopri
# AppleScriptObjC     _ctypes_test        formatter           random
# Audio_mac           _curses             fpformat            re
# Automator           _curses_panel       fractions           readline
# BaseHTTPServer      _elementtree        ftplib              redis
# Bastion             _functools          functools           repr
# CFNetwork           _hashlib            future_builtins     requests
# CFOpenDirectory     _heapq              gc                  resource
# CGIHTTPServer       _hotshot            genericpath         rexec
# ...

# %% [markdown]
# #Data type_数据类型：inter float string boolean
#
#
# Number（数字）包括 int,long,float,double,
# String（字符串）

# %%
import ctypes
dir(ctypes)# C语言变量类型（包括指针类型）。
# Out:
# ['ARRAY',
#  'ArgumentError',
#  'Array',
#  'BigEndianStructure',
#  'CDLL',
#  'CFUNCTYPE',
#  'DEFAULT_MODE',
#  'LibraryLoader',
#  'LittleEndianStructure',
#  'POINTER',
#  'PYFUNCTYPE',
#  'PyDLL',
#  'RTLD_GLOBAL',
#  'RTLD_LOCAL',
#  'SetPointerType',
#  'Structure',
#  'Union',
#  '_CFuncPtr',
#  '_FUNCFLAG_CDECL',
#  '_FUNCFLAG_PYTHONAPI',
#  '_FUNCFLAG_USE_ERRNO',
#  '_FUNCFLAG_USE_LASTERROR',
#  '_Pointer',
#  '_SimpleCData',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__version__',
#  '_c_functype_cache',
#  '_calcsize',
#  '_cast',
#  '_cast_addr',
#  '_check_size',
#  '_ctypes_version',
#  '_dlopen',
#  '_endian',
#  '_memmove_addr',
#  '_memset_addr',
#  '_os',
#  '_pointer_type_cache',
#  '_reset_cache',
#  '_string_at',
#  '_string_at_addr',
#  '_sys',
#  '_wstring_at',
#  '_wstring_at_addr',
#  'addressof',
#  'alignment',
#  'byref',
#  'c_bool',
#  'c_buffer',
#  'c_byte',
#  'c_char',
#  'c_char_p',
# ...

# %% [markdown]
# #Data structures_数据结构
#
# List（列表）         例如：[1,2,3],[1,2,3,[1,2,3],4]
# Dictionary（字典）   例如：{1:"nihao",2:"hello"}
# Set
# Frozenset
# Tuple（元组）        例如：(1,2,3,abc)
# File（文件）         例如：f = open(a.txt,rw)

# %% [markdown]
# #Decorator_装饰器

# %% [markdown]
# #Algorithm_ 算法
